# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * List of popular language for Data Scientist
# * List of commonly used libraries for Data Scientist
# * List of tools for Data Science
# * Example of simple aritmathic expression in Jupyter Notebook

# %% [markdown]
# ## Author
# Agung Ghani Kramawijaya

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. R
# 2. Pyhton
# 3. Julia
# 4. Scala
# 5. Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. dplyr
# 2. ggplot
# 3. pandas
# 4. numpy
# 5. scikit-learn

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyter Notebook|
# |Rstudio|
# |Visual Studio Code|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
200/6
# Out:
# 33.333333333333336
